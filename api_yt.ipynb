# %% [markdown]
# <a href="https://colab.research.google.com/github/debsk/DataSicence/blob/master/api_yt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from googleapiclient.discovery import build

# %%
youTubeApiKey="AIzaSyBR_nTMIVM99gMv_XMh7y0En9fYjpp4n88"

# %%
youtube = build('youtube','v3', developerKey=youTubeApiKey)

# %%
# Extraindo videos de uma Playlist 
playlistId = 'RDCMUC70mr11REaCqgKke7DPJoLg' #pp
playlistName = 'PP'
nextPage_token = None

# %%
playlist_videos = []

while True:
  res = youtube.playlistItems().list(part='snippet', playlistId = playlistId, maxResults=50, pageToken=nextPage_token).execute()
  playlist_videos += res['items']
  
  nextPage_token = res.get('nestPageToken')

  if nextPage_token is None:
    break

# %%
playlist_videos
# Out:
# [{'etag': 'a25UF_ElNrhtsYUE30cyQUqqUVo',
#   'id': 'UkRDTVVDNzBtcjExUkVhQ3FnS2tlN0RQSm9MZy5iTUxiZjEwdUMwWQ',
#   'kind': 'youtube#playlistItem',
#   'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#    'channelTitle': 'YouTube',
# ...
